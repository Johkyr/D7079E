# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchvision.models import resnet18
import numpy as np
from scipy.optimize import differential_evolution

# Selects GPU or CPU depending if CUDA (Nvidia) drivers are available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Image Preprocessing
# Mean and standard deviation values gathered from 
# https://github.com/huyvnphan/PyTorch_CIFAR10/tree/master
#transform = torchvision.transforms.Compose([
#    torchvision.transforms.ToTensor(), # Convert raw image to PyTorch tensor/format
#    torchvision.transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)) # Normalize with mean and standard deviation
#])

mean = torch.tensor([0.4914, 0.4822, 0.4465]).view(3, 1, 1)
std  = torch.tensor([0.2470, 0.2435, 0.2616]).view(3, 1, 1)
transform = torchvision.transforms.ToTensor() 

# Loads the CIFAR10 test set (10 000 images)
# Train - False / True | decides to load either train set (50 000 images) or test set (10 000 images)
# Download = True | download test set if not already downloaded
# Transform = transform each image with the above defined transform pipeline
testset = torchvision.datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)

# DataLoader - Batches the images. In this example we only set size to 1 (one image per "batch")
# Program could be written without this, but it's a simple way to shuffle the images to get new images each test
testloader = torch.utils.data.DataLoader(testset, batch_size=1, shuffle=True)

# Initialize model
model = resnet18(weights=None) # Load resnet18 without weights (default weights are for ImageNet and not CIFAR10)
model.fc = nn.Linear(model.fc.in_features, 10) # Change final layer to output 10 classes (CIFAR10). Default for ImageNet is 1000 classes
model.load_state_dict(torch.load("resnet18_cifar10.pth", map_location=device)) # Load trained weighs from file
model.to(device).eval(); # Move model to GPU or CPU depending on what device is selected. Eval() sets model to evaluation mode instead of train mode

# %%
# Predicts image label using specified model
@torch.no_grad() # Disable gradient tracking for faster computation (not needed if not training)
def predict(model, image):
    # image is unnormalized tensor from dataset
    img_norm = (image - mean.to(image.device)) / std.to(image.device)
    logits = model(img_norm.unsqueeze(0))
    probs = torch.softmax(logits, dim=1)
    conf, pred = probs.max(dim=1)
    return pred.item(), conf.item()


def make_fitness_function(img_raw, label):
    def fitness(x):
        x_pos = int(np.clip(round(x[0]), 0, 31))
        y_pos = int(np.clip(round(x[1]), 0, 31))

        adv_raw = img_raw.clone()

        r = np.clip(x[2], 0, 255)
        g = np.clip(x[3], 0, 255)
        b = np.clip(x[4], 0, 255)

        adv_raw[:, y_pos, x_pos] = torch.tensor(
            [r, g, b], device=img_raw.device
        ) / 255.0  # keep in [0,1]

        # normalize like in predict
        adv_norm = (adv_raw - mean.to(img_raw.device)) / std.to(img_raw.device)

        with torch.no_grad():
            probs = torch.softmax(model(adv_norm.unsqueeze(0)), dim=1)[0]

        return probs[label].item()
    return fitness

# %%
def differential_evolution_attack(img, label, pop_size=15, max_iter=100):
    bounds = [(0, 31), (0, 31), (0, 255), (0, 255), (0, 255)]
    fitness = make_fitness_function(img, label)
    
    generation = 0
    best_fitness = float('inf')
    
    print(f"Initial best fitness (prob of current label): {fitness([16, 16, 0.5, 0.5, 0.5]):.4f}")
    
    def callback(candidate, convergence):
        nonlocal generation, best_fitness
        generation += 1
        
        current_fitness = fitness(candidate)
        if current_fitness < best_fitness:
            best_fitness = current_fitness
        
        if generation % 20 == 0:
            print(f"Iter {generation:3d} | best fitness: {best_fitness:.4f}")
        
        x_pos = int(round(candidate[0]))
        y_pos = int(round(candidate[1]))
        r, g, b = candidate[2], candidate[3], candidate[4]
        
        adv = img.clone()
        adv[:, y_pos, x_pos] = torch.tensor([r, g, b], device=img.device).clamp(0, 1)
        
        adv_pred, adv_conf = predict(model, adv)
        if adv_pred != label:
            print(f"Early stop at iter {generation}: label changed to {adv_pred} (conf {adv_conf:.3f})")
            return True
        
        return False
    
    result = differential_evolution(
        fitness,
        bounds,
        strategy="best1bin",   # close to their DE/rand/1 style
        maxiter=max_iter,      # keep 100 if you want to match
        popsize=80,            # 80 * 5 dims ≈ 400 individuals
        mutation=(0.5, 0.5),   # fixed F = 0.5
        recombination=0.0,     # ~ no crossover
        callback=callback,
        atol=0, tol=0,
        polish=False
    )
    
    x = int(round(result.x[0]))
    y = int(round(result.x[1]))
    r, g, b = result.x[2], result.x[3], result.x[4]
    
    return (x, y), (r, g, b), result.fun

# %%
def run_one_pixel_attack(num_images=20, pop_size=15, max_iter=100):
    success_count = 0
    tried = 0
    
    for images, labels in testloader:
        img = images[0].to(device)
        true_label = labels[0].item()
        
        pred, conf = predict(model, img)
        
        if pred != true_label:
            continue
        
        if tried >= num_images:
            print(f"\nFinished {tried} correctly classified images.")
            print(f"Success rate: {success_count/tried*100:.2f}%")
            return
        
        tried += 1
        class_name = testset.classes[true_label]
        print(f"\nAttacking image {tried} | true = {class_name} | model_pred = {class_name} ({conf:.3f})")
        
        (x, y), (r, g, b), _ = differential_evolution_attack(img, pred, pop_size, max_iter)
        
        adv_img = img.clone()
        adv_img[:, y, x] = torch.tensor([r, g, b], device=img.device).clamp(0, 1)
        
        adv_pred, adv_conf = predict(model, adv_img)
        
        if adv_pred != pred:
            success_count += 1
            print(f"→ SUCCESS: {testset.classes[pred]} → {testset.classes[adv_pred]} (conf {adv_conf:.3f})")
        else:
            print(f"→ Failed: still {testset.classes[adv_pred]} (conf {adv_conf:.3f})")
    
    print(f"\nFinished {tried} correctly classified images.")
    print(f"Success rate: {success_count/tried*100:.2f}%")

run_one_pixel_attack(num_images=20, pop_size=300, max_iter=60)
# Out:
# Attacking image 1 | true = ship | model_pred = ship (0.803)
# Initial best fitness (prob of current label): 0.9183
# Iter  20 | best fitness: 0.6139
# Iter  40 | best fitness: 0.5992
# Iter  60 | best fitness: 0.5966
# → Failed: still ship (conf 0.669)
#
# Attacking image 2 | true = truck | model_pred = truck (0.593)
# Initial best fitness (prob of current label): 0.5793
# Iter  20 | best fitness: 0.3351
# Iter  40 | best fitness: 0.3180
# Iter  60 | best fitness: 0.3156
# → Failed: still truck (conf 0.509)
#
# Attacking image 3 | true = truck | model_pred = truck (0.581)
# Initial best fitness (prob of current label): 0.5673
# Iter  20 | best fitness: 0.3158
# Iter  40 | best fitness: 0.3091
# Iter  60 | best fitness: 0.3081
# → Failed: still truck (conf 0.308)
#
# Attacking image 4 | true = frog | model_pred = frog (0.752)
# Initial best fitness (prob of current label): 0.7727
# Iter  20 | best fitness: 0.6639
# Iter  40 | best fitness: 0.6548
# Iter  60 | best fitness: 0.6499
# ...
